# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
nltk.download('punkt')
import pandas
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/AG News/test.txt')
test = file.read()
test = test.splitlines()
file.close()

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/AG News/train.txt')
train = file.read()
train = train.splitlines()
file.close()

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/AG News/trainLabels.txt')
trainLabels = file.read()
trainLabels = trainLabels.splitlines()
file.close()

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/AG News/testLabels.txt')
testLabels = file.read()
testLabels = testLabels.splitlines()
file.close()

# %%
Y_train = []
Y_test = []

for label in testLabels:
  if label == "1":
    Y_test.append(0)
  elif label == "2":
    Y_test.append(1)

for label in trainLabels:
  if label == "1":
    Y_train.append(0)
  elif label == "2":
    Y_train.append(1)

X_train = train
X_test = test

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 60000
# 3800

# %%
import pandas as pd

# %%
X = []
Y = []
index = 0
for sample in X_train:
  X.append(sample)
  Y.append(Y_train[index])
  index +=1
index = 0
for sample in X_test:
  X.append(sample)
  Y.append(Y_test[index])
  index +=1

d = {'Sentences':X,'Label':Y}
df = pd.DataFrame(d)

# %%
df.to_csv('/content/drive/MyDrive/COMP550 Final Project/AG News/AGNews.csv')

# %%
def removeStop(StringArray):
    tokens = []
    for i in StringArray: #### Tokenize each sentence
        tokens.append(word_tokenize(i))
    tokensRS = []
    for i in tokens: #### Remove stop words
        tokensRS.append([word for word in i if not word in stopwords.words()])
    reString = []
    for i in tokensRS: ### put back into string format
        reString.append((" ").join(i))
    return reString

# %%
stop_words = set(stopwords.words('english'))

# %%
def fastRemoveStop(StringArray):
  filtered_sentences = []
  for sample in StringArray:
    words = word_tokenize(sample)
    filtered_words = []
    for word in words:
      if word not in stop_words:
        filtered_words.append(word)
    filtered_sentences.append(' '.join(filtered_words))
  return filtered_sentences

# %% [markdown]
# OPTIONAL

# %%
X_train_noStops = fastRemoveStop(X_train)
X_test_noStops = fastRemoveStop(X_test)
