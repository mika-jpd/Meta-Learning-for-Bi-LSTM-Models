# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/Amazon Reviews/neg_test.txt')
neg_test = file.read()
neg_test = neg_test.splitlines()
file.close()

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/Amazon Reviews/pos_test.txt')
pos_test = file.read()
pos_test = pos_test.splitlines()
file.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/Amazon Reviews/pos_train.txt')
pos_train = file.read()
pos_train = pos_train.splitlines()
file.close()

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/Amazon Reviews/neg_train.txt')
neg_train = file.read()
neg_train = neg_train.splitlines()
file.close()

# %% [markdown]
# Testing

# %%
X_train = []
Y_train = []
X_test = []
Y_test = []


for sample in neg_test:
  X_test.append(sample)
  Y_test.append(0)
for sample in pos_test:
  X_test.append(sample)
  Y_test.append(1)
for sample in neg_train:
  X_train.append(sample)
  Y_train.append(0)
for sample in pos_train:
  X_train.append(sample)
  Y_train.append(1)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 3600000
# 400000

# %%
import pandas as pd

# %%
X = []
Y = []
index = 0
for sample in X_train:
  X.append(sample)
  Y.append(Y_train[index])
  index +=1
index = 0
for sample in X_test:
  X.append(sample)
  Y.append(Y_test[index])
  index +=1

#d = {'Sentences':X,'Label':Y}
#df = pd.DataFrame(d)

# %%
print(len(X))
# Out:
# 4000000

# %%
df.to_csv('/content/drive/MyDrive/COMP550 Final Project/Amazon Reviews/Amazon.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f338191cbf4e> in <module>()
# ----> 1 df.to_csv('/content/drive/MyDrive/COMP550 Final Project/Amazon Reviews/Amazon.csv')
#
# NameError: name 'df' is not defined

# %% [markdown]
# OPTIONAL

# %%
X_train_noStops = []
X_test_noStops = []

for sample in X_train:
  X_train_noStops.append(removeStop(sample))
for sample in X_test:
  X_test_noStops.append(removeStop(sample))

print(X_train_noStops)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-00b306a31b24> in <module>()
#       3
#       4 for sample in X_train:
# ----> 5   X_train_noStops.append(removeStop(sample))
#       6 for sample in X_test:
#       7   X_test_noStops.append(removeStop(sample))
#
# NameError: name 'removeStop' is not defined

# %%
path_data = "/content/drive/MyDrive/COMP550 Final Project/IMDB.csv"
df = pd.read_csv(path_data)
Y = pd.Series.to_numpy(df['Label'])
X = pd.Series.to_numpy(df['Sentences'])

# %%
index = 0
split = 64
Dlabels = []
Dtrain = []
for sentence in X:
  if index % split == 0:
    Dtrain.append(sentence)
    Dlabels.append(Y[index])
  index +=1

# %%
print(len(Dtrain))
# Out:
# 62500

# %%
c = {'Sentences':Dtrain,'Label':Dlabels}
cf = pd.DataFrame(c)

# %%
cf.to_csv('/content/drive/MyDrive/COMP550 Final Project/Amazon Reviews/AmazonMini.csv')
