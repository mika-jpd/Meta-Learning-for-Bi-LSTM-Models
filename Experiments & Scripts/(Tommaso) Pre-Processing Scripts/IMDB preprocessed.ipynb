# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
nltk.download('punkt')
import pandas as pd
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/IMDB reviews/neg_test.txt')
neg_test = file.read()
neg_test = neg_test.splitlines()
file.close()

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/IMDB reviews/pos_test.txt')
pos_test = file.read()
pos_test = pos_test.splitlines()
file.close()

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/IMDB reviews/neg_train.txt')
neg_train = file.read()
neg_train = neg_train.splitlines()
file.close()

# %%
file = open('/content/drive/MyDrive/COMP550 Final Project/IMDB reviews/pos_train.txt')
pos_train = file.read()
pos_train = pos_train.splitlines()
file.close()

# %%
X_train = []
Y_train = []
X_test = []
Y_test = []


for sample in neg_test:
  X_test.append(sample)
  Y_test.append(0)
for sample in pos_test:
  X_test.append(sample)
  Y_test.append(1)
for sample in neg_train:
  X_train.append(sample)
  Y_train.append(0)
for sample in pos_train:
  X_train.append(sample)
  Y_train.append(1)

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatizer_dataset(dataset):
  lemm_text = []
  for review in dataset:
    words = word_tokenize(review)
    lemm_text.append(' '.join(lemmatizer(words)))
  return lemm_text

# %%
def lemmatizer(text):
  lemm_text = []
  for word in text:
    lemm_text.append(wordnet_lemmatizer.lemmatize(word))
  return lemm_text

# %%
X_train_lemm = lemmatizer_dataset(X_train)

# %%
print(X_train_lemm[0])
print(X_train[0])
# Out:
# welltremors i the original started off in and i found the movie quite enjoyable to watch however they proceeded to make tremor ii and iii trust me those movie started going downhill right after they finished the first one i mean as blaster now only god himself is capable of answering the question why in god name would they create another one of these dumpster dive of a movie tremor iv can not be considered a bad movie in fact it can not be even considered an epitome of a bad movie for it life up to more than that a i attempted to sit though it i noticed that my eye started to bleed and i hoped profusely that the little girl from the ring would crawl through the tv and kill me did they really think that dressing the people who had stared in the other movie up a though they were from the wild west would make the movie with the exact same occurrence any better honestly i would never suggest buying this movie i mean there are cheaper way to find thing that burn well
# ...

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 24998
# 24998

# %%
stop_words = set(stopwords.words('english'))

# %%
def fastRemoveStop(StringArray):
  filtered_sentences = []
  for sample in StringArray:
    words = word_tokenize(sample)
    filtered_words = []
    for word in words:
      if word not in stop_words:
        filtered_words.append(word)
    filtered_sentences.append(' '.join(filtered_words))
  return filtered_sentences

# %% [markdown]
# BUNCH UP TOGETHER TRAIN AND TEST AND MAKE PANDAS DATAFRAME

# %%
X = []
Y = []
index = 0
for sample in X_train:
  X.append(sample)
  Y.append(Y_train[index])
  index +=1
index = 0
for sample in X_test:
  X.append(sample)
  Y.append(Y_test[index])
  index +=1

d = {'Sentences':X,'Label':Y}
df = pd.DataFrame(d)

# %%
df.to_csv('/content/drive/MyDrive/COMP550 Final Project/IMDB reviews/IMDB.csv')

/content/drive/MyDrive/COMP550 Final Project/Amazon.csv

# %% [markdown]
# OPTIONAL

# %%
X_train_noStops = []
X_test_noStops = []

for sample in X_train:
  X_train_noStops.append(removeStop(sample))
for sample in X_test:
  X_test_noStops.append(removeStop(sample))
